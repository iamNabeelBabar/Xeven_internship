# %% [markdown]
# **Day 5**

# %%
hours = [1, 2, 3, 4, 5]
marks = [40, 50, 60, 70, 80]

print("Hours:", hours)
print("Marks:", marks)

# %%
marks = [35, 40, 42, 70, 75, 80]

low = []
high = []

for m in marks:
    if m < 50:
        low.append(m)
    else:
        high.append(m)

print("Low group:", low)
print("High group:", high)

# %%
action = "study"

if action == "study":
    reward = 10
else:
    reward = -5

print("Action:", action)
print("Reward:", reward)

# %%
action = "study"

if action == "study":
    reward = 10
else:
    reward = -5

print("Action:", action)
print("Reward:", reward)

# %%
# Decision Tree Step 2

income = 25000

if income < 30000:
    print("Reject loan (Low income)")
else:
    print("Proceed to credit score check")
